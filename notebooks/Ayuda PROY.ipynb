# %% [markdown]
# # AYUDA PARA PROYECTO

# %% [markdown]
# **EXPORTAR NUEVO DF CREADO EN FORMATO EXCEL A DRIVE**
#
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')  # Solo necesitas hacerlo una vez
#
# # Guardar archivo Excel en una carpeta específica de tu Drive
# ruta_guardado = '/content/drive/MyDrive/tu_carpeta/df_completo.xlsx'
# df_interp.to_excel(ruta_guardado, index=False)
# ```

# %% [markdown]
# **MOSTRAR TODA UNA COLUMNA (NO SOLO UNOS CUANTOS VALORES)**
#
#
#
# ```
# pd.set_option('display.max_rows', None)  # Muestra todas las filas
#
# print(df_interp['% _emigrantes'])  # Reemplaza con la columna que quieras
# ```
# **RESTABLECER LA OPCIÓN POR DEFECTO (SÓLO UNOS CUANTOS VALROES)**
#
#
#
# ```
# pd.reset_option('display.max_rows')
# ```

# %% [markdown]
# **VER RESULTADO IMNPUTACIÓN**
#
#
#
# ```
# import matplotlib.pyplot as plt
#
# pais = 'Argentina'  # cámbialo para ver otros países
# columna = '% _emigrantes'
#
# df_pais = df[df['country'] == pais]
# df_interp_pais = df_interp[df_interp['country'] == pais]
#
# plt.plot(df_pais['year'], df_pais[columna], 'o-', label='Original', alpha=0.6)
# plt.plot(df_interp_pais['year'], df_interp_pais[columna], 'x--', label='Imputado', alpha=0.8)
# plt.title(f'{columna} en {pais}')
# plt.xlabel('Año')
# plt.ylabel(columna)
# plt.legend()
# plt.grid(True)
# plt.show()
# ```

# %% [markdown]
# **COMPARAR MEDIAS Y DV DESPUÉS DE IMPUTAR**
#
#
#
# ```
# print("Media original (sin NaNs):", df[columna].mean())
# print("Media imputada:", df_interp[columna].mean())
#
# print("Desviación estándar original:", df[columna].std())
# print("Desviación estándar imputada:", df_interp[columna].std())
# ```
